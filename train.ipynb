# %%
# %run /content/drive/MyDrive/poly-Project/model.ipynb import build_model
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 16  448         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 16  64         ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16  0          ['activation_20[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 32  9248        ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 32  128        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)  0           ['activation_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 48)   13872       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 48)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 48)   20784       ['activation_23[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 48)  192         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 48)   0           ['batch_normalization_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 48)  0           ['activation_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 64)   27712       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_25[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 64)   36928       ['max_pooling2d_7[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_27[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_27[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 64)  0           ['activation_28[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 128)  0           ['up_sampling2d_4[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_29[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_29[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 64)  0           ['activation_30[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 112)  0           ['up_sampling2d_5[0][0]',
#                                                                   'activation_24[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 48)   48432       ['concatenate_5[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 48)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 64, 64, 48)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 48)   20784       ['activation_31[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 48)  192         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 64, 64, 48)   0           ['batch_normalization_31[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 48  0          ['activation_32[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 80  0           ['up_sampling2d_6[0][0]',
#                                 )                                 'activation_22[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 32  23072       ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 128, 128, 32  128        ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 32  9248        ['activation_33[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 128, 128, 32  128        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 32  0          ['activation_34[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 48  0           ['up_sampling2d_7[0][0]',
#                                 )                                 'activation_20[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 16  6928        ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 16  64         ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 16  2320        ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 16  64         ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 1)  17          ['activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 256, 256, 1)  0           ['conv2d_37[0][0]']
#
# ==================================================================================================
# Total params: 414,401
# Trainable params: 412,865
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %%
# %run /content/drive/MyDrive/poly-Project/data.ipynb import load_data, tf_dataset
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 800 100 100
# 800 100 100

# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger, TensorBoard

# from model import build_model  ----->>>>>   %run /content/drive/MyDrive/Harshit/Polyp-Segmentation-using-UNET-in-TensorFlow-2.0-master/model.ipynb import build_model
# from data import load_data, tf_dataset  ----->>>>>   %run <add_path_of_file_with_file_name_(niche_maine_apna_example_use_kiya_hai_waise_hi)> import load_data, tf_dataset

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

# %%
if __name__ == "__main__":
    ## Dataset
    path = "/content/drive/MyDrive/poly-Project/Kvasir-SEG"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(path)

    ## Hyperparameters
    batch = 8
    lr = 1e-4
    epochs = 20

    train_dataset = tf_dataset(train_x, train_y, batch=batch)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch)

    model = build_model()

    opt = tf.keras.optimizers.Adam(lr)
    metrics = ["acc", tf.keras.metrics.Recall(), tf.keras.metrics.Precision(), iou]
    model.compile(loss="binary_crossentropy", optimizer=opt, metrics=metrics)

    callbacks = [
        ModelCheckpoint("/content/drive/MyDrive/poly-Project/files/model.h5"),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
        CSVLogger("/content/drive/MyDrive/poly-Project/files/data.csv"),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
    ]

    train_steps = len(train_x)//batch
    valid_steps = len(valid_x)//batch

    if len(train_x) % batch != 0:
        train_steps += 1
    if len(valid_x) % batch != 0:
        valid_steps += 1

    model.fit(train_dataset,
        validation_data=valid_dataset,
        epochs=epochs,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps,
        callbacks=callbacks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 4
#       1 if __name__ == "__main__":
#       2     ## Dataset
#       3     path = "/content/drive/MyDrive/poly-Project/Kvasir-SEG"
# ----> 4     (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(path)
#       6     ## Hyperparameters
#       7     batch = 8
#
# NameError: name 'load_data' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
